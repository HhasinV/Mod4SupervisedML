# %% [markdown]
# # First Classification 🐥🐥

# %% [markdown]
# 0. Import usual libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score, RocCurveDisplay, ConfusionMatrixDisplay
from sklearn.model_selection import cross_val_score
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) # to avoid deprecation warnings

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
# setting Jedha color palette as default
pio.templates["jedha"] = go.layout.Template(
    layout_colorway=["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]
)
pio.templates.default = "jedha"
pio.renderers.default = "svg" # to be replaced by "iframe" if working on JULIE
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/2489756972.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 22, in <module>
#     from pandas.compat import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/__init__.py", line 28, in <module>
#     from pandas.compat.pyarrow import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/pyarrow.py", line 9, in <module>
#     import pyarrow as pa
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/2489756972.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 9, in <module>
#     from pandas.core.dtypes.dtypes import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/dtypes/dtypes.py", line 28, in <module>
#     from pandas._libs import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/2489756972.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 65, in <module>
#     from pandas.core import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 9, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 55, in <module>
#     from pandas.core.computation import expressions
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 22, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/home/henintsoa/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/2489756972.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 79, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 56, in <module>
#     from pandas.core import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 54, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/home/henintsoa/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/2489756972.py", line 4, in <module>
#     from sklearn.model_selection import train_test_split
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/__init__.py", line 70, in <module>
#     from sklearn.base import clone  # noqa: E402
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 19, in <module>
#     from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py", line 9, in <module>
#     from sklearn.utils._chunking import gen_batches, gen_even_slices
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from sklearn.utils._param_validation import Interval, validate_params
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from sklearn.utils.validation import _is_arraylike_not_scalar
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py", line 24, in <module>
#     from sklearn.utils._array_api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py", line 20, in <module>
#     from sklearn.utils.fixes import parse_version
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/fixes.py", line 389, in <module>
#     import pyarrow
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
# ----> 4 from sklearn.model_selection import train_test_split
#       5 from sklearn.pipeline import Pipeline
#       6 from sklearn.impute import SimpleImputer
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)
#     111     "compose",
#     112 ]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:19
#      17 from sklearn._config import config_context, get_config
#      18 from sklearn.exceptions import InconsistentVersionWarning
# ---> 19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
#      20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _convert_to_numpy,
#      27     _is_numpy_namespace,
#      28     _max_precision_float_dtype,
#      29     get_namespace,
#      30     get_namespace_and_device,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df, is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:20
#      18 from sklearn.externals.array_api_compat import numpy as np_compat
#      19 from sklearn.utils._dataframe import is_df_or_series
# ---> 20 from sklearn.utils.fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/fixes.py:389
#     387 PYARROW_VERSION_BELOW_17 = False
#     388 try:
# --> 389     import pyarrow
#     391     pyarrow_version = parse_version(pyarrow.__version__)
#     392     if pyarrow_version < parse_version("17.0.0"):
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py:65
#      63 _gc_enabled = _gc.isenabled()
#      64 _gc.disable()
# ---> 65 import pyarrow.lib as _lib
#      66 if _gc_enabled:
#      67     _gc.enable()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/lib.pyx:36, in init pyarrow.lib()
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# 1. Download the following data using this link : ```https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Machine+Learning+Supervis%C3%A9/R%C3%A9gression+logistique+Cross+validation/Datasets/ex2data1.txt``` and put it into a DataFrame
#
# Pay attention to the header of the DataFrame, there's something annoying with it! Look at the documentation of `pd.read_csv()` to find a way of solving the problem 🤓

# %%
# Import dataset
data = pd.read_csv('https://full-stack-bigdata-datasets.s3.eu-west-3.amazonaws.com/Machine+Learning+Supervis%C3%A9/R%C3%A9gression+logistique+Cross+validation/Datasets/ex2data1.txt',
                   header=None)
print("Shape of dataset: ", data.shape)
data.head()

# %% [markdown]
# 2. Rename the columns using the following names :
#
# "Col_1" / "Col_2" / "Target"

# %%
col_names = {
    0: "Col_1",
    1: "Col_2",
    2: "Target"
}

data = data.rename(columns= col_names)

data.head()

# %% [markdown]
# 3. Visualize the data as a scatter plot where the two different classes are displayed with different colors.

# %%
# !pip install --upgrade kaleido

# %%
fig = px.scatter(data, x = 'Col_1', y = 'Col_2', color = data['Target'].astype('str'), labels = {'color': 'Target'})
fig.show()

# %% [markdown]
# 4. Separate X and y into two different objects.

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "Target"

X = data.drop(target_variable, axis = 1)
Y = data.loc[:,target_variable]

print("...Done.")
print()

print('Y : ')
print(Y.head())
print()
print('X :')
print(X.head())

# %% [markdown]
# 5. Split the data into a train set and a test set

# %%
## Statify splitting when you're training a classification model !
X_train, X_test, Y_train, Y_test = train_test_split(X ,Y ,test_size = 0.2, stratify = Y, random_state = 42)

# %% [markdown]
# 6. Do you think that the two variables "Col_1" and "Col_2" would be good predictors of the target?

# %%
# Univariate analysis
# Distribution of each numeric variable
num_features = ['Col_1', 'Col_2']
for f in num_features:
    fig = px.histogram(data, f, color = 'Target', facet_row = 'Target', histnorm = 'probability')
    fig.show()

# %% [markdown]
# 7. Analyze the explanatory variables, what preprocessings are necessary? Make the preprocessings.

# %%
data.describe(include = 'all')

# %% [markdown]
# Some good news:
# * There are no missing values in this dataset --> no imputation needed
# * Although we're dealing with a classification problem, the _Target_ is alrady encoded as 0s and 1s, so we don't need to use the LabelEncoder
# * All the features (_Col1_ and _Col2_) are numeric, so we just want to apply a StandardScaler to the whole array X

# %%
# Data must be normalized to guarantee that we can interpret the model's parameters
print("Performing preprocessings on train set...")
print(X_train.head())
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
print('...Done.')
print(X_train[0:5]) # MUST use this syntax because X_train is a numpy array and not a pandas DataFrame anymore
print()

# Preprocessings on test set
print("Performing preprocessings on test set...")
print(X_test.head())
X_test = scaler.transform(X_test) ### NO fit on X_test
print('...Done.')
print(X_test[0:5,:]) # MUST use this syntax because X_test is a numpy array and not a pandas DataFrame anymore
print()

# %% [markdown]
# 8. Use the LogisticRegression function from sklearn in order to create a model instance and train it.

# %%
classifier = LogisticRegression()
classifier.fit(X_train, Y_train)
LogisticRegression()

# %% [markdown]
# 9. What's the accuracy on the train set ? and on the test set ?
#
# Find a way of evaluating the scores without explicitely computing the model's predictions.

# %%
# The method .score() from LogisticRegression() returns the accuracy!
print('Train accuracy : {}\nTest accuracy : {}'.format(classifier.score(X_train, Y_train), classifier.score(X_test, Y_test)))

# %% [markdown]
# 10. What's the average score with a cross-validation using K=10, what's the score's standard deviation?

# %%
scores = cross_val_score(classifier,X_train, Y_train, cv=10)
avg = scores.mean()
std = scores.std()
print('Cross-validated accuracy : {}\nstandard deviation : {}'.format(avg, std))

# %% [markdown]
# 11. Is the model underfitting/overfitting?

# %% [markdown]
# 12. Create objects containing the model's predictions on the train/test sets, as well as the estimated probabilities

# %%
# Predictions on training set
print("Predictions on training set...")
Y_train_pred = classifier.predict(X_train)
print("...Done.")
print(Y_train_pred[:5])
print()

# It's also possible to get the probabilities estimated by the model:
print("Probabilities on training set...")
Y_train_proba = classifier.predict_proba(X_train)
print("...Done.")
print(Y_train_proba[:5])
print()

# %%
# Predictions on test set
print("Predictions on test set...")
Y_test_pred = classifier.predict(X_test)
print("...Done.")
print(Y_test_pred[:5])
print()

# It's also possible to get the probabilities estimated by the model:
print("Probabilities on test set...")
Y_test_proba = classifier.predict_proba(X_test)
print("...Done.")
print(Y_test_proba[:5])
print()

# %% [markdown]
# 13. Display the confusion matrix derived from the predictions performed by your model on the training data, do the same on your test data. What do you think of your model's performance, do you think it would generalize well on unknown data?

# %%
# Visualize confusion matrices
_ , ax = plt.subplots() # Get subplot from matplotlib
ax.set(title="Confusion Matrix on Train set") # Set a title that we will add into ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(classifier, X_train, Y_train, ax=ax) # ConfusionMatrixDisplay from sklearn
plt.show()

_ , ax = plt.subplots() # Get subplot from matplotlib
ax.set(title="Confusion Matrix on Test set") # Set a title that we will add into ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(classifier, X_test, Y_test, ax=ax) # ConfusionMatrixDisplay from sklearn
plt.show()

# %% [markdown]
# **From the questions above, we can deduce that the generalized performances are very good ! Indeed, the test accuracy is comparable to the train accuracy and we can see in the confusion matrix that the prediction errors are very rare 🥳🥳**

# %% [markdown]
# 14. Produce the ROC curve for the train set and the test set

# %%
# Visualize ROC curves
_ , ax = plt.subplots() # Get subplot from matplotlib
ax.set(title="ROC Curve on Train set") # Set a title that we will add into ConfusionMatrixDisplay
RocCurveDisplay.from_estimator(classifier, X_train, Y_train, ax=ax) # RocCurveDisplay from sklearn
plt.show()

_ , ax = plt.subplots() # Get subplot from matplotlib
ax.set(title="ROC Curve on Test set") # Set a title that we will add into ConfusionMatrixDisplay
RocCurveDisplay.from_estimator(classifier, X_test, Y_test, ax=ax) # RocCurveDisplay from sklearn
plt.show()

# %% [markdown]
# **The area under the curves is quite close to 1. This means that the model is robust as it does not depend on the choice of the threshold used in the logistic regression.**

# %% [markdown]
# 15. Create a DataFrame named predictions_df_train that contains the following values on train set:
# * explanatory variables "Col_1" and "Col_2"
# * the target variable Y
# * the predictions Y_pred
# * the estimated probabilites from the classifier.
#
# Sort the values according to the probabilities (in ascending order).

# %%
predictions_df_train = pd.DataFrame(X_train, columns = ['Col_1', 'Col_2'])
predictions_df_train["Y"] = Y_train.tolist()
predictions_df_train["Y_pred"] = Y_train_pred.tolist()
predictions_df_train["Proba"] = Y_train_proba[:,1]
predictions_df_train = predictions_df_train.sort_values(by="Proba")
predictions_df_train.head()

# %% [markdown]
# 16. Plot the probabilities as a function of the variables "Col_1" and "Col_2". Change the marker color according to the values of "Y_pred".

# %%
# Visualize the model
# Visualize predictions on training Set
fig = px.scatter_3d(predictions_df_train, x = 'Col_1', y = 'Col_2', z = 'Proba', title = "training set", color = 'Y_pred')
fig.show()

# %% [markdown]
# 17. Use the library mlxtend to plot the decision boundary of the model. You might need to install it before :
# ```python
# !pip install mlxtend
# ```
# This documentation page might help you 😉 : http://rasbt.github.io/mlxtend/api_subpackages/mlxtend.plotting/

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /home/henintsoa/anaconda3/lib/python3.11/site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.17.0)
# Requirement already satisfied: numpy>=2.3.5 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (2.4.1)
# Requirement already satisfied: pandas>=2.3.3 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (3.0.0)
# Requirement already satisfied: scikit-learn>=1.8.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (23.1)
# Requirement already satisfied: pillow>=8 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (10.2.0)
# Requirement already satisfied: pyparsing>=3 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from matplotlib>=3.10.8->mlxtend) (2.8.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.8.0->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.16.0)

# %%
from mlxtend.plotting import plot_decision_regions


X = predictions_df_train.iloc[:,:2].values
Y = predictions_df_train.loc[:,"Y"].values

# Plotting decision regions
plot_decision_regions(X, Y, clf=classifier, legend=2)

# Adding axes annotations
plt.xlabel('Col_1')
plt.ylabel('Col_2')
plt.title('Logistic Regression Decision Boundary')
plt.show()
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_74748/3087582375.py", line 1, in <module>
#     from mlxtend.plotting import plot_decision_regions
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/plotting/__init__.py", line 13, in <module>
#     from .pca_correlation_graph import plot_pca_correlation_graph
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/plotting/pca_correlation_graph.py", line 11, in <module>
#     from mlxtend.feature_extraction import PrincipalComponentAnalysis
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/feature_extraction/__init__.py", line 7, in <module>
#     from .linear_discriminant_analysis import LinearDiscriminantAnalysis
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/feature_extraction/linear_discriminant_analysis.py", line 11, in <module>
#     from .._base import _BaseModel
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/_base/__init__.py", line 8, in <module>
#     from ._classifier import _Classifier
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/mlxtend/_base/_classifier.py", line 12, in <module>
#     from sklearn.utils._tags import ClassifierTags, Tags, TargetTags
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/__init__.py", line 70, in <module>
#     from sklearn.base import clone  # noqa: E402
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 20, in <module>
#     from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py", line 9, in <module>
#     from sklearn.utils._chunking import gen_batches, gen_even_slices
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_chunking.py", line 11, in <module>
#     from sklearn.utils._param_validation import Interval, validate_params
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 17, in <module>
#     from sklearn.utils.validation import _is_arraylike_not_scalar
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py", line 24, in <module>
#     from sklearn.utils._array_api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py", line 20, in <module>
#     from sklearn.utils.fixes import parse_version
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/sklearn/utils/fixes.py", line 389, in <module>
#     import pyarrow
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#       4 X = predictions_df_train.iloc[:,:2].values
#       5 Y = predictions_df_train.loc[:,"Y"].values
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/plotting/__init__.py:13
#      11 from .heatmap import heatmap
#      12 from .learning_curves import plot_learning_curves
# ---> 13 from .pca_correlation_graph import plot_pca_correlation_graph
#      14 from .plot_confusion_matrix import plot_confusion_matrix
#      15 from .plot_linear_regression import plot_linear_regression
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/plotting/pca_correlation_graph.py:11
#       8 import pandas as pd
#      10 from mlxtend.externals.adjust_text import adjust_text
# ---> 11 from mlxtend.feature_extraction import PrincipalComponentAnalysis
#      14 def corr2_coeff(A, B):
#      15     """
#      16     Compute correlation coefficients and return as a np array
#      17     """
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/feature_extraction/__init__.py:7
#       1 # Sebastian Raschka 2014-2026
#       2 # mlxtend Machine Learning Library Extensions
#       3 # Author: Sebastian Raschka <sebastianraschka.com>
#       4 #
#       5 # License: BSD 3 clause
# ----> 7 from .linear_discriminant_analysis import LinearDiscriminantAnalysis
#       8 from .principal_component_analysis import PrincipalComponentAnalysis
#       9 from .rbf_kernel_pca import RBFKernelPCA
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/feature_extraction/linear_discriminant_analysis.py:11
#       1 # Sebastian Raschka 2014-2026
#       2 # mlxtend Machine Learning Library Extensions
#       3 #
#    (...)
#       6 #
#       7 # License: BSD 3 clause
#       9 import numpy as np
# ---> 11 from .._base import _BaseModel
#      14 class LinearDiscriminantAnalysis(_BaseModel):
#      15     """
#      16     Linear Discriminant Analysis Class
#      17
#    (...)
#      37
#      38     """
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/_base/__init__.py:8
#       1 # Sebastian Raschka 2014-2026
#       2 # mlxtend Machine Learning Library Extensions
#       3 # Author: Sebastian Raschka <sebastianraschka.com>
#       4 #
#       5 # License: BSD 3 clause
#       7 from ._base_model import _BaseModel
# ----> 8 from ._classifier import _Classifier
#       9 from ._cluster import _Cluster
#      10 from ._iterative_model import _IterativeModel
#
# File ~/anaconda3/lib/python3.11/site-packages/mlxtend/_base/_classifier.py:12
#       9 from time import time
#      11 import numpy as np
# ---> 12 from sklearn.utils._tags import ClassifierTags, Tags, TargetTags
#      15 class _Classifier(object):
#      16     _estimator_type = "classifier"
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/__init__.py:70
#      62 # `_distributor_init` allows distributors to run custom init code.
#      63 # For instance, for the Windows wheel, this is used to pre-load the
#      64 # vcomp shared library runtime for OpenMP embedded in the sklearn/.libs
#    (...)
#      67 # later is linked to the OpenMP runtime to make it possible to introspect
#      68 # it and importing it first would fail if the OpenMP dll cannot be found.
#      69 from sklearn import __check_build, _distributor_init  # noqa: E402 F401
# ---> 70 from sklearn.base import clone  # noqa: E402
#      71 from sklearn.utils._show_versions import show_versions  # noqa: E402
#      73 _submodules = [
#      74     "calibration",
#      75     "cluster",
#    (...)
#     111     "compose",
#     112 ]
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/base.py:20
#      18 from sklearn.exceptions import InconsistentVersionWarning
#      19 from sklearn.utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from sklearn.utils._missing import is_pandas_na, is_scalar_nan
#      21 from sklearn.utils._param_validation import validate_parameter_constraints
#      22 from sklearn.utils._repr_html.base import ReprHTMLMixin, _HTMLDocumentationLinkMixin
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/__init__.py:9
#       7 from sklearn.utils import metadata_routing
#       8 from sklearn.utils._bunch import Bunch
# ----> 9 from sklearn.utils._chunking import gen_batches, gen_even_slices
#      11 # Make _safe_indexing importable from here for backward compat as this particular
#      12 # helper is considered semi-private and typically very useful for third-party
#      13 # libraries that want to comply with scikit-learn's estimator API. In particular,
#      14 # _safe_indexing was included in our public API documentation despite the leading
#      15 # `_` in its name.
#      16 from sklearn.utils._indexing import _safe_indexing, resample, shuffle
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_chunking.py:11
#       8 import numpy as np
#      10 from sklearn._config import get_config
# ---> 11 from sklearn.utils._param_validation import Interval, validate_params
#      14 def chunk_generator(gen, chunksize):
#      15     """Chunk generator, ``gen`` into lists of length ``chunksize``. The last
#      16     chunk may have a length less than ``chunksize``."""
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:17
#      14 from scipy.sparse import csr_matrix, issparse
#      16 from sklearn._config import config_context, get_config
# ---> 17 from sklearn.utils.validation import _is_arraylike_not_scalar
#      20 class InvalidParameterError(ValueError, TypeError):
#      21     """Custom exception to be raised when the parameter of a class/method/function
#      22     does not have a valid type or value.
#      23     """
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/validation.py:24
#      18 from sklearn import get_config as _get_config
#      19 from sklearn.exceptions import (
#      20     DataConversionWarning,
#      21     NotFittedError,
#      22     PositiveSpectrumWarning,
#      23 )
# ---> 24 from sklearn.utils._array_api import (
#      25     _asarray_with_order,
#      26     _convert_to_numpy,
#      27     _is_numpy_namespace,
#      28     _max_precision_float_dtype,
#      29     get_namespace,
#      30     get_namespace_and_device,
#      31 )
#      32 from sklearn.utils._dataframe import is_pandas_df, is_pandas_df_or_series
#      33 from sklearn.utils._isfinite import FiniteStatus, cy_isfinite
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/_array_api.py:20
#      18 from sklearn.externals.array_api_compat import numpy as np_compat
#      19 from sklearn.utils._dataframe import is_df_or_series
# ---> 20 from sklearn.utils.fixes import parse_version
#      22 # TODO: complete __all__
#      23 __all__ = ["xpx"]  # we import xpx here just to re-export it, need this to appease ruff
#
# File ~/anaconda3/lib/python3.11/site-packages/sklearn/utils/fixes.py:389
#     387 PYARROW_VERSION_BELOW_17 = False
#     388 try:
# --> 389     import pyarrow
#     391     pyarrow_version = parse_version(pyarrow.__version__)
#     392     if pyarrow_version < parse_version("17.0.0"):
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/__init__.py:65
#      63 _gc_enabled = _gc.isenabled()
#      64 _gc.disable()
# ---> 65 import pyarrow.lib as _lib
#      66 if _gc_enabled:
#      67     _gc.enable()
#
# File ~/anaconda3/lib/python3.11/site-packages/pyarrow/lib.pyx:36, in init pyarrow.lib()
#
# ImportError: numpy.core.multiarray failed to import
