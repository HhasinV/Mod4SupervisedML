# %% [markdown]
# # Decision Tree Classifier 🌳🌳
# ## Importing libraries and dataset

# %% [markdown]
# 0. Import usual libraries

# %%
# !pip install --upgrade pyarrow scikit-learn
# Out:
# Requirement already satisfied: pyarrow in /home/henintsoa/anaconda3/lib/python3.11/site-packages (23.0.0)
# Requirement already satisfied: scikit-learn in /home/henintsoa/anaconda3/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/henintsoa/anaconda3/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import  OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, f1_score, ConfusionMatrixDisplay, RocCurveDisplay, classification_report

import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
# setting Jedha color palette as default
pio.templates["jedha"] = go.layout.Template(
    layout_colorway=["#4B9AC7", "#4BE8E0", "#9DD4F3", "#97FBF6", "#2A7FAF", "#23B1AB", "#0E3449", "#015955"]
)
pio.templates.default = "jedha"
pio.renderers.default = "svg" # to be replaced by "iframe" if working on JULIE
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_209756/4224257536.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 65, in <module>
#     from pandas.core import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/ops/__init__.py", line 9, in <module>
#     from pandas.core.ops.array_ops import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/ops/array_ops.py", line 55, in <module>
#     from pandas.core.computation import expressions
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/computation/expressions.py", line 22, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/computation/check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/home/henintsoa/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/numexpr/__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.4.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 607, in run_forever
#     self._run_once()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/base_events.py", line 1922, in _run_once
#     handle._run()
#   File "/home/henintsoa/anaconda3/lib/python3.11/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_209756/4224257536.py", line 1, in <module>
#     import pandas as pd
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/__init__.py", line 46, in <module>
#     from pandas.core.api import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/api.py", line 27, in <module>
#     from pandas.core.arrays import Categorical
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/arrow/array.py", line 79, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py", line 56, in <module>
#     from pandas.core import (
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py", line 54, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/pandas/compat/_optional.py", line 158, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "/home/henintsoa/anaconda3/lib/python3.11/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/home/henintsoa/anaconda3/lib/python3.11/site-packages/bottleneck/__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 14
#      11 from sklearn.metrics import accuracy_score, f1_score, ConfusionMatrixDisplay, RocCurveDisplay, classification_report
#      13 import matplotlib.pyplot as plt
# ---> 14 import plotly.express as px
#      15 import plotly.graph_objects as go
#      16 import plotly.io as pio
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/__init__.py:27
#      11 if np is None:
#      12     raise ImportError(
#      13         """\
#      14 Plotly Express requires numpy to be installed. You can install numpy using pip with:
#    (...)
#      24 """
#      25     )
# ---> 27 from ._imshow import imshow
#      28 from ._chart_types import (  # noqa: F401
#      29     scatter,
#      30     scatter_3d,
#    (...)
#      67     density_mapbox,
#      68 )
#      71 from ._core import (  # noqa: F401
#      72     set_mapbox_access_token,
#      73     defaults,
#      74     get_trendline_results,
#      75     NO_COLOR,
#      76 )
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_imshow.py:11
#       8 from plotly.utils import image_array_to_data_uri
#      10 try:
# ---> 11     import xarray
#      13     xarray_imported = True
#      14 except ImportError:
#
# File ~/anaconda3/lib/python3.11/site-packages/xarray/__init__.py:1
# ----> 1 from xarray import testing, tutorial
#       2 from xarray.backends.api import (
#       3     load_dataarray,
#       4     load_dataset,
#    (...)
#       8     save_mfdataset,
#       9 )
#      10 from xarray.backends.zarr import open_zarr
#
# File ~/anaconda3/lib/python3.11/site-packages/xarray/testing.py:10
#       7 import numpy as np
#       8 import pandas as pd
# ---> 10 from xarray.core import duck_array_ops, formatting, utils
#      11 from xarray.core.dataarray import DataArray
#      12 from xarray.core.dataset import Dataset
#
# File ~/anaconda3/lib/python3.11/site-packages/xarray/core/duck_array_ops.py:36
#      33 from numpy.core.multiarray import normalize_axis_index  # type: ignore[attr-defined]
#      34 from numpy.lib.stride_tricks import sliding_window_view  # noqa
# ---> 36 from xarray.core import dask_array_ops, dtypes, nputils
#      37 from xarray.core.parallelcompat import get_chunked_array_type, is_chunked_array
#      38 from xarray.core.pycompat import array_type, is_duck_dask_array
#
# File ~/anaconda3/lib/python3.11/site-packages/xarray/core/dask_array_ops.py:3
#       1 from __future__ import annotations
# ----> 3 from xarray.core import dtypes, nputils
#       6 def dask_rolling_wrapper(moving_func, a, window, min_count=None, axis=-1):
#       7     """Wrapper to apply bottleneck moving window funcs on dask arrays"""
#
# File ~/anaconda3/lib/python3.11/site-packages/xarray/core/dtypes.py:43
#      33 NINF = AlwaysLessThan()
#      36 # Pairs of types that, if both found, should be promoted to object dtype
#      37 # instead of following NumPy's own type-promotion rules. These type promotion
#      38 # rules match pandas instead. For reference, see the NumPy type hierarchy:
#      39 # https://numpy.org/doc/stable/reference/arrays.scalars.html
#      40 PROMOTE_TO_OBJECT: tuple[tuple[type[np.generic], type[np.generic]], ...] = (
#      41     (np.number, np.character),  # numpy promotes to character
#      42     (np.bool_, np.character),  # numpy promotes to character
# ---> 43     (np.bytes_, np.unicode_),  # numpy promotes to unicode
#      44 )
#      47 def maybe_promote(dtype):
#      48     """Simpler equivalent of pandas.core.common._maybe_promote
#      49
#      50     Parameters
#    (...)
#      57     fill_value : Valid missing value for the promoted dtype.
#      58     """
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/__init__.py:778, in __getattr__(attr)
#     775     raise AttributeError(__former_attrs__[attr], name=None)
#     777 if attr in __expired_attributes__:
# --> 778     raise AttributeError(
#     779         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     780         f"{__expired_attributes__[attr]}",
#     781         name=None
#     782     )
#     784 if attr == "chararray":
#     785     warnings.warn(
#     786         "`np.chararray` is deprecated and will be removed from "
#     787         "the main namespace in the future. Use an array with a string "
#     788         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.unicode_` was removed in the NumPy 2.0 release. Use `np.str_` instead.

# %% [markdown]
# 1. Import the bl.txt dataset and display the first few lines.

# %%
df = pd.read_csv('bl.txt')

# %%
print("done")
df.head()
# Out:
# done
#   balance  left_weight  left_distance  right_weight  right_distance
# 0       B            1              1             1               1
# 1       R            1              1             1               2
# 2       R            1              1             1               3
# 3       R            1              1             1               4
# 4       R            1              1             1               5

# %% [markdown]
# 2. Display a descriptive statistic table

# %%
df.describe(include='all')
# Out:
#        balance  left_weight  left_distance  right_weight  right_distance
# count      625   625.000000     625.000000    625.000000      625.000000
# unique       3          NaN            NaN           NaN             NaN
# top          R          NaN            NaN           NaN             NaN
# freq       288          NaN            NaN           NaN             NaN
# mean       NaN     3.000000       3.000000      3.000000        3.000000
# std        NaN     1.415346       1.415346      1.415346        1.415346
# min        NaN     1.000000       1.000000      1.000000        1.000000
# 25%        NaN     2.000000       2.000000      2.000000        2.000000
# 50%        NaN     3.000000       3.000000      3.000000        3.000000
# 75%        NaN     4.000000       4.000000      4.000000        4.000000
# max        NaN     5.000000       5.000000      5.000000        5.000000

# %%
df['balance'].value_counts()
# Out:
# balance
# R    288
# L    288
# B     49
# Name: count, dtype: int64

# %% [markdown]
# 3. What is the dataset shape?

# %%
df.shape
# Out:
# (625, 5)

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# 4. Separate the target variable "balance" into a Y object and the explanatory variables into a X object.

# %%
# Separate target variable Y from features X
print("Separating labels from features...")
target_variable = "balance"

X = df.drop(target_variable, axis = 1)
Y = df.loc[:,target_variable]

print("...Done.")
print()

print('Y : ')
print(Y.head())
print()
print('X :')
print(X.head())
# Out:
# Separating labels from features...
# ...Done.
#
# Y :
# 0    B
# 1    R
# 2    R
# 3    R
# 4    R
# Name: balance, dtype: str
#
# X :
#    left_weight  left_distance  right_weight  right_distance
# 0            1              1             1               1
# 1            1              1             1               2
# 2            1              1             1               3
# 3            1              1             1               4
# 4            1              1             1               5

# %% [markdown]
# 5. Split the data between a train set with 70% of the data and use the rest to build a test set with random_state=42

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.3, random_state=42, stratify = Y)

# %% [markdown]
# ## Comparing Decision Trees: Gini or Entropy Criterion?

# %% [markdown]
# 6. Create an instance of a 'DecisionTreeClassifier' with GINI criterion, and fit it on training data. Beforehand, make any preprocessing that you think is necessary.

# %%
### Preprocessings ###
# With a decision tree, there's no need to normalize the numerical variables !

# Encode label
encoder = LabelEncoder()
Y_train = encoder.fit_transform(Y_train)
Y_test = encoder.transform(Y_test)

# %%
classifier_gini = DecisionTreeClassifier(criterion="gini")
classifier_gini.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# 7. Display your tree using `plot_tree` from [sklearn.tree](https://scikit-learn.org/stable/modules/generated/sklearn.tree.plot_tree.html)

# %%
from sklearn.tree import plot_tree

class_names = encoder.inverse_transform([0, 1, 2])

plt.figure(figsize=(20,20))
a = plot_tree(classifier_gini,
              feature_names=X.columns,
              class_names=class_names,
              filled=True,
              rounded=True,
              fontsize=14)

# %% [markdown]
# 8. Create an instance of a DecisionTreeClassifier using the entropy criterion.

# %%
classifier_entropy = DecisionTreeClassifier(criterion="entropy")
classifier_entropy.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# 9. Display the tree

# %%
plt.figure(figsize=(20,10))
a = plot_tree(classifier_entropy,
              feature_names=X.columns,
              class_names=class_names,
              filled=True,
              rounded=True,
              fontsize=14)

# %% [markdown]
# 10. Check if the observation defined as X_new  [4, 4, 3, 3] is classified as left

# %%
X_new = pd.DataFrame(data = [[4,4,3,3]], columns = ["left_weight", "left_distance", "right_weight", "right_distance"])
classifier_entropy.predict(X_new)
# Out:
# array([1])

# %%
encoder.inverse_transform([1])
# Out:
# array(['L'], dtype=object)

# %%
classifier_gini.predict(X_new)
# Out:
# array([1])

# %% [markdown]
# 11. Use the gini classifier to make predictions on the test set

# %%
y_pred_gini = classifier_gini.predict(X_test)
y_pred_gini
# Out:
# array([2, 1, 0, 2, 1, 2, 2, 2, 0, 1, 2, 2, 0, 0, 2, 1, 1, 1, 1, 2, 2, 2,
#        1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1, 2, 2, 0, 2, 2, 2, 2, 0, 1, 1,
#        2, 2, 2, 2, 2, 1, 0, 1, 1, 1, 2, 1, 2, 2, 2, 2, 1, 1, 2, 1, 2, 1,
#        0, 1, 1, 0, 1, 1, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 2, 2, 1, 2, 1, 2,
#        1, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 1, 2, 0, 1,
#        2, 1, 2, 1, 1, 0, 2, 0, 1, 2, 1, 1, 1, 2, 1, 1, 0, 2, 1, 0, 2, 1,
#        2, 2, 0, 2, 1, 2, 1, 1, 1, 1, 2, 1, 1, 1, 2, 2, 0, 1, 2, 2, 0, 1,
#        1, 2, 2, 2, 2, 2, 0, 1, 1, 2, 1, 2, 1, 1, 0, 1, 2, 0, 1, 1, 0, 1,
#        2, 2, 1, 0, 2, 2, 1, 0, 1, 0, 0, 2])

# %% [markdown]
# 12. Use the entropy classifier on the test set to make predictions

# %%
y_pred_entropy = classifier_entropy.predict(X_test)
y_pred_entropy
# Out:
# array([2, 1, 2, 2, 1, 2, 2, 2, 0, 1, 2, 2, 0, 0, 2, 1, 1, 1, 1, 2, 2, 2,
#        1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1, 2, 2, 0, 2, 2, 2, 1, 0, 2, 1,
#        1, 0, 2, 2, 2, 1, 0, 1, 1, 1, 2, 1, 2, 0, 1, 2, 1, 1, 2, 1, 2, 1,
#        0, 1, 1, 0, 0, 1, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 2, 2, 1, 1, 1, 2,
#        0, 1, 1, 1, 1, 2, 1, 2, 1, 1, 2, 1, 2, 1, 1, 1, 1, 1, 1, 2, 0, 1,
#        2, 1, 2, 1, 0, 2, 2, 0, 1, 2, 1, 1, 2, 2, 1, 2, 0, 2, 1, 0, 2, 1,
#        2, 2, 0, 2, 1, 2, 1, 1, 1, 1, 2, 1, 1, 1, 0, 2, 0, 1, 2, 2, 0, 1,
#        1, 2, 2, 2, 2, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 1, 2, 1, 1, 1, 0, 1,
#        2, 0, 1, 0, 2, 2, 1, 0, 1, 0, 0, 2])

# %% [markdown]
# 13. Compare each prediction made with the gini and entropy classifier, what proportion of predictions are identical?

# %% [markdown]
# You can either compare each prediction using a for loop over all observations' indices, otherwise you simply loop over the two prediction vectors using the ```zip``` function
# You can figure out what ```zip``` does by running
# ```
# A=[1,2,3]
# B=["a","b","c"]
#
# for a, b in zip(A,B):
#   print(a,b)
# ```
#
# The numbers appearing in the solution will not necessarily the ones you will obtain depending on random operations you ran on your data.

# %%
for item1, item2 in zip(y_pred_entropy, y_pred_gini):
    print(f"y_pred_entropy: {item1}, y_pred_gini: {item2}")
# Out:
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 0, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 0, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 2, y_pred_gini: 2
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 1, y_pred_gini: 1
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 0, y_pred_gini: 0
# y_pred_entropy: 2, y_pred_gini: 2

# %%
import numpy as np

# Boolean mask: True where predictions are identical
agree_mask = (y_pred_gini == y_pred_entropy)

count = (~agree_mask).sum()

print("on the test set, there are {} examples that have different predictions from Gini and Entropy".format(count))
print("Which corresponds to a percentage of {}% ".format(np.round(count / len(y_pred_gini) * 100, 3)))
# Out:
# on the test set, there are 19 examples that have different predictions from Gini and Entropy
# Which corresponds to a percentage of 10.106%

# %% [markdown]
# 14. What's the accuracy of the gini classifier?

# %%
classifier_gini.score(X_test, Y_test)
# Out:
# 0.7553191489361702

# %% [markdown]
# 15. What's the accuracy of the entropy classifier?

# %%
classifier_entropy.score(X_test, Y_test)
# Out:
# 0.7446808510638298

# %% [markdown]
# 16. Display the "entropy" model's confusion matrix, what do you notice?

# %%
# Visualize confusion matrices
_ , ax = plt.subplots() # Get subplot from matplotlib
ax.set(title="Confusion Matrix on Test set") # Set a title that we will add into ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(classifier_entropy, X_test, Y_test, ax=ax) # ConfusionMatrixDisplay from sklearn
plt.show()

# %% [markdown]
# **--> Most errors correspond to examples of class 'B' that are misclassified as 'R' or 'L'**

# %% [markdown]
# 17. Display the classification report for both models on both training and testing data. Do the models perform well? Do they overfit ?
#
# *Hint : have a look at scikit-learn's documentation about available metric functions* 😉

# %%
print(classification_report(y_true = Y_test, y_pred=classifier_entropy.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.06      0.13      0.09        15
#            1       0.87      0.83      0.85        87
#            2       0.89      0.77      0.82        86
#
#     accuracy                           0.74       188
#    macro avg       0.61      0.58      0.59       188
# weighted avg       0.81      0.74      0.78       188

# %%
print(classification_report(y_true = Y_test, y_pred = classifier_gini.predict(X_test)))

# %% [markdown]
# ## Fighting overfitting

# %% [markdown]
# 18. How would you fight overfitting while still using decision tree classifiers? Try to find the set of hyper parameters that maximize the performances of the model on the test set. Did the model perform better ? Are there still ways to improve the model?

# %% [markdown]
# ## Feature engineering

# %% [markdown]
# 19. Try and create new variables in order to improve the model's performance. Make again the preprocessings. And train a new model with gini criterion.
